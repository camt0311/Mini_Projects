# %% [markdown]
# # CSE 158 FA20: Assignment 1
# Name: Cameron Thomas <br>
# PID: A13978010

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import gzip
import random
import scipy
from collections import defaultdict
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import json
import string
from nltk.stem.porter import PorterStemmer
from sklearn import linear_model
import heapq
import math
from sklearn.svm import SVC
from tqdm import tqdm
from tqdm.notebook import trange, tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import accuracy_score
from sklearn.feature_extraction.text import CountVectorizer
from scipy.spatial.distance import pdist, squareform
from scipy.io import arff
from io import StringIO
from sklearn.metrics import confusion_matrix
from sklearn.metrics import balanced_accuracy_score
from scipy.stats import pearsonr
from sklearn.pipeline import Pipeline
import nltk
from nltk.stem.porter import *
from nltk.corpus import stopwords
import scipy.optimize
import ast
from sklearn.metrics import accuracy_score
from sklearn import metrics
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from tqdm.notebook import tqdm
from time import sleep
import pickle
from sklearn import svm

# %% [markdown]
# tar xvzf assignment1.tar.gz

# %%
os.listdir('assignment1')
# Out:
# ['train.json.gz',
#  'pairs_Category.txt',
#  'test_Category.json.gz',
#  'train_Category.json.gz',
#  'pairs_Played.txt',
#  'baselines.py',
#  'pairs_Hours.txt']

# %%
def readGz(f):
    for l in gzip.open(f):
        yield eval(l)
data = list(readGz('assignment1/train_Category.json.gz'))

# %%
data[0]
# Out:
# {'userID': 'u74382925',
#  'genre': 'Adventure',
#  'early_access': False,
#  'reviewID': 'r75487422',
#  'hours': 4.1,
# ...

# %%
X_train_raw = data[:165000]
y_train_raw = data[:165000]
X_valid_raw = data[165000:]
y_valid_raw = data[165000:]

# %%
all_reviews = [d['text'] for d in tqdm(data)]

# %%
all_reviews
# Out:
# ['Short Review:\nA good starting chapter for this series, despite the main character being annoying (for now) and a short length. The story is good and actually gets more interesting. Worth the try.\nLong Review:\nBlackwell Legacy is the first on the series of (supposedly) 5 games that talks about the main protagonist, Rosangela Blackwell, as being a so called Medium, and in this first chapter we get to know how her story will start and how she will meet her adventure companion Joey...and really, that\'s really all for for now and that\'s not a bad thing, because in a way this game wants to show how hard her new job is, and that she cannot escape her destiny as a medium.\nMy biggest complain for this chapter, except the short length, it\'s the main protagonist being a "bit" too annoying to be likeable, and most of her dialogues will always be about complaining or just be annoyed. Understandable, sure, but lighten\' up will ya!?\nHowever, considering that in the next installments she 
# ...

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(tqdm(all_reviews))
y = [d['genreID'] for d in tqdm(data)]
y_train = [d['genreID'] for d in tqdm(y_train_raw)]
y_valid = [d['genreID'] for d in tqdm(y_valid_raw)]
pickle.dump(vectorizer.vocabulary_,open("feature.pkl","wb"))

# %%
mod = LogisticRegression(C=1)
X_train = X[:165000]

# %%
mod.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
X_valid = X[165000:]
pred_valid = mod.predict(X_valid)
accuracy_score(y_valid, pred_valid)
# Out:
# 0.7492

# %%
pred_lr = mod.predict(tfidf)
index = 0
predictions = open("predictions_Category2.txt", 'w')
predictions.write("userID-reviewID,prediction\n")
for l in readGz("assignment1/test_Category.json.gz"):
    predictions.write(l['userID'] + '-' + l['reviewID'] + "," + str(pred_lr[index]) + "\n")
    index += 1
predictions.close()

# %%
mod2 = LogisticRegression(C=0.001)
X_train = X[:165000]
mod2.fit(X_train, y_train)
X_valid = X[165000:]
pred_valid = mod2.predict(X_valid)
accuracy_score(y_valid, pred_valid)
# Out:
# 0.5532

# %%
mod3 = LogisticRegression(C=0.01)
X_train = X[:165000]
mod3.fit(X_train, y_train)
X_valid = X[165000:]
pred_valid = mod3.predict(X_valid)
accuracy_score(y_valid, pred_valid)
# Out:
# 0.5952

# %%
mod6 = LogisticRegression(C=0.1)
X_train = X[:165000]
mod6.fit(X_train, y_train)
X_valid = X[165000:]
pred_valid = mod6.predict(X_valid)
accuracy_score(y_valid, pred_valid)
# Out:
# 0.7058

# %%
mod4 = LogisticRegression(C=10)
X_train = X[:165000]
mod4.fit(X_train, y_train)
X_valid = X[165000:]
pred_valid = mod4.predict(X_valid)
accuracy_score(y_valid, pred_valid)
# Out:
# 0.7477

# %%
mod5 = LogisticRegression(C=100)
X_train = X[:165000]
mod5.fit(X_train, y_train)
X_valid = X[165000:]
pred_valid = mod5.predict(X_valid)
accuracy_score(y_valid, pred_valid)
# Out:
# 0.7452

# %%
mod6 = LogisticRegression(solver='lbfgs', C=1, multi_class='auto', max_iter=2000)
X_train = X[:165000]
mod6.fit(X_train, y_train)
X_valid = X[165000:]
pred_valid = mod6.predict(X_valid)
accuracy_score(y_valid, pred_valid)
# Out:
# 0.7531

# %%
testing = list(readGz("assignment1/test_Category.json.gz"))
test_review = [d['text'] for d in tqdm(testing)]

# %%
transformer = TfidfTransformer()
loaded_vec = CountVectorizer(decode_error="replace",vocabulary=pickle.load(open("feature.pkl", "rb")))
tfidf = transformer.fit_transform(loaded_vec.fit_transform(test_review))

# %%
clf = svm.LinearSVC(random_state=0, tol=1e-5)

# %%
clf.fit(X_train, y_train)
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=0, tol=1e-05,
#           verbose=0)

# %%
pred_valid = clf.predict(X_valid)
accuracy_score(y_valid, pred_valid)
# Out:
# 0.7587

# %%
clf3 = svm.LinearSVC()
clf3.fit(X_train, y_train)
pred_valid = clf3.predict(X_valid)
accuracy_score(y_valid, pred_valid)
# Out:
# 0.7587

# %%
clf4 = svm.LinearSVC(C=0.001)
clf4.fit(X_train, y_train)
pred_valid = clf4.predict(X_valid)
accuracy_score(y_valid, pred_valid)
# Out:
# 0.5724

# %%
clf5 = svm.LinearSVC(C=0.01)
clf5.fit(X_train, y_train)
pred_valid = clf5.predict(X_valid)
accuracy_score(y_valid, pred_valid)
# Out:
# 0.6934

# %%
clf6 = svm.LinearSVC(C=0.1)
clf6.fit(X_train, y_train)
pred_valid = clf6.predict(X_valid)
accuracy_score(y_valid, pred_valid)
# Out:
# 0.749

# %%
clf7 = svm.LinearSVC(C=10)
clf7.fit(X_train, y_train)
pred_valid = clf7.predict(X_valid)
accuracy_score(y_valid, pred_valid)
# Out:
# 0.741

# %%
clf8 = svm.LinearSVC(C=100)
clf8.fit(X_train, y_train)
pred_valid = clf8.predict(X_valid)
accuracy_score(y_valid, pred_valid)
# Out:
# 0.7134

# %%
clf9 = svm.LinearSVC(class_weight='balanced')
clf9.fit(X_train, y_train)
pred_valid = clf9.predict(X_valid)
accuracy_score(y_valid, pred_valid)
# Out:
# 0.7289

# %%
clf10 = svm.LinearSVC(max_iter=2000)
clf10.fit(X_train, y_train)
pred_valid = clf10.predict(X_valid)
accuracy_score(y_valid, pred_valid)
# Out:
# 0.7587

# %%
from sklearn.ensemble import RandomForestClassifier
clf2 = RandomForestClassifier()

# %%
clf2.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
pred_valid = clf2.predict(X_valid)
accuracy_score(y_valid, pred_valid)
# Out:
# 0.6703

# %%
# clf best accuracy

# %%
pred_svc = clf.predict(tfidf)

# %%
index = 0
predictions = open("predictions_Category2.txt", 'w')
predictions.write("userID-reviewID,prediction\n")
for l in readGz("assignment1/test_Category.json.gz"):
    predictions.write(l['userID'] + '-' + l['reviewID'] + "," + str(pred_svc[index]) + "\n")
    index += 1
predictions.close()
